# %% [markdown]
# <a href="https://colab.research.google.com/github/jit0341/python_practice_project/blob/main/23_9_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print("Hello," , name)

greet("Jitendra")
greet("Saumya")
# Out:
# Hello, Jitendra
# Hello, Saumya

# %%
def add(a,b):
  return a + b
print(add(3,7))
# Out:
# 10

# %%
def add(a,b):
  return a + b
print(add(5,7))
# Out:
# 12

# %%
def greet(name = "Guest"):
  print("Hello," , name )
greet()

def greet(name = "Friend"):
  print("Hello," , name)
greet()

def greet():
  name = input("Enter your name:")
  print("Hello," , name)

greet()
# Out:
# Hello, Guest
# Hello, Friend
# Enter your name:Hari
# Hello, Hari

# %%
def square(x):
  return x**2
  print(x)
square(6)

print("----Even or Odd---")
def even_or_odd(x):
  if x % 2 == 0:
    return "even"
  else:
    return "odd"

print(even_or_odd(3))
print(even_or_odd(8))

def maximum(a,b,c):
  if a >= b and a >= c:
    return a
  elif b >= a and b >= c:
    return b
  else:
    return c
print(maximum(33,34,36))
print(maximum(34,53,65))
# Out:
# ----Even or Odd---
# odd
# even
# 36
# 65

# %%
def maximum(a, b, c):
    return max(a, b, c)

print(maximum(36, 32, 33))   # 36

def minimum(a,b,c):
  return min(a,b,c)

print(minimum(23,12,45))
# Out:
# 36
# 12

# %%
def reverse_string(x):
  return x[::-1]
reverse_string("Python")
# Out:
# 'nohtyP'

# %%
def factorial(n):
  result = 1
  for i in range(1,n+1):
    result = result * i
  return result

print(factorial(5))
print(factorial(4))
print(factorial(0))
# Out:
# 120
# 24
# 1
