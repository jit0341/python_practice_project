# %% [markdown]
# <a href="https://colab.research.google.com/github/jit0341/python_practice_project/blob/main/symbols_cheat_sheet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# symbols_cheat_sheet2.py
# Interactive Symbols & Emojis Cheat Sheet

def general():
    print("\n=== ✅ General Indicators ===")
    print("✔ Success (\u2714)")
    print("✖ Error (\u2716)")
    print("⚠ Warning (\u26A0)")
    print("❌ Cross (\u274C)")
    print("✅ Check (\u2705)")
    print("ℹ Info (\u2139)")

def fun():
    print("\n=== 🎉 Fun / Feedback ===")
    print("🎉 Celebration (\U0001F389)")
    print("👏 Clap (\U0001F44F)")
    print("🔥 Fire (\U0001F525)")
    print("⚡ Power (\u26A1)")
    print("🌟 Star (\U0001F31F)")
    print("💡 Idea (\U0001F4A1)")

def math_logic():
    print("\n=== 🔢 Math & Logic ===")
    print("π Pi (\u03C0)")
    print("√ Square Root (\u221A)")
    print("∑ Summation (\u2211)")
    print("∞ Infinity (\u221E)")
    print("≠ Not Equal (\u2260)")
    print("≤ Less or Equal (\u2264)")
    print("≥ Greater or Equal (\u2265)")

def arrows():
    print("\n=== 🔀 Arrows ===")
    print("→ Right (\u2192)")
    print("← Left (\u2190)")
    print("↑ Up (\u2191)")
    print("↓ Down (\u2193)")
    print("↔ Left-Right (\u2194)")
    print("⇨ Heavy Right (\u21E8)")

def games():
    print("\n=== 🎮 Games / Console ===")
    print("🎲 Dice (\U0001F3B2)")
    print("🎯 Target (\U0001F3AF)")
    print("🏆 Trophy (\U0001F3C6)")
    print("❤️ Heart (\u2764)")
    print("💀 Skull (\U0001F480)")
    print("👑 Crown (\U0001F451)")

def system_tools():
    print("\n=== ⚙ System / Tools ===")
    print("🖥 Computer (\U0001F5A5)")
    print("📂 Folder (\U0001F4C2)")
    print("📊 Chart (\U0001F4CA)")
    print("🔑 Key (\U0001F511)")
    print("🔒 Locked (\U0001F512)")
    print("🔓 Unlocked (\U0001F513)")

def demo_usage():
    print("\n=== 📝 Demo Usage ===")
    print("✅ Correct Answer!")
    print("❌ Wrong Answer!")
    print("⚡ Python is powerful!")
    print("Your reward: 🏆 + 🎉")
    print("Math example: √16 =", 16**0.5)


# --- Menu System ---
while True:
    print("\n=== Emoji & Symbols Cheat Sheet ===")
    print("1. General Indicators")
    print("2. Fun / Feedback")
    print("3. Math & Logic")
    print("4. Arrows")
    print("5. Games / Console")
    print("6. System / Tools")
    print("7. Demo Usage")
    print("0. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        general()
    elif choice == "2":
        fun()
    elif choice == "3":
        math_logic()
    elif choice == "4":
        arrows()
    elif choice == "5":
        games()
    elif choice == "6":
        system_tools()
    elif choice == "7":
        demo_usage()
    elif choice == "0":
        print("Goodbye! 👋")
        break
    else:
        print("❌ Invalid choice, try again.")
# Out:
# === Emoji & Symbols Cheat Sheet ===
# 1. General Indicators
# 2. Fun / Feedback
# 3. Math & Logic
# 4. Arrows
# 5. Games / Console
# 6. System / Tools
# 7. Demo Usage
# 0. Exit
# Enter your choice: 6
#
# === ⚙ System / Tools ===
# 🖥 Computer (🖥)
# 📂 Folder (📂)
# 📊 Chart (📊)
# 🔑 Key (🔑)
# 🔒 Locked (🔒)
# 🔓 Unlocked (🔓)
#
# === Emoji & Symbols Cheat Sheet ===
# 1. General Indicators
# 2. Fun / Feedback
# 3. Math & Logic
# 4. Arrows
# 5. Games / Console
# 6. System / Tools
# 7. Demo Usage
# 0. Exit
# Enter your choice: 1
#
# === ✅ General Indicators ===
# ✔ Success (✔)
# ✖ Error (✖)
# ⚠ Warning (⚠)
# ❌ Cross (❌)
# ✅ Check (✅)
# ℹ Info (ℹ)
#
# === Emoji & Symbols Cheat Sheet ===
# 1. General Indicators
# 2. Fun / Feedback
# 3. Math & Logic
# 4. Arrows
# 5. Games / Console
# 6. System / Tools
# 7. Demo Usage
# 0. Exit
# Enter your choice: 0
# Goodbye! 👋
